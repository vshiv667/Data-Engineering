# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # Gain Actionable Insights from Twitter Data
#
# In this capstone project, you will use Structured Streaming to gain insight from streaming Twitter data.
#
# The executive team would like to have access to some key business metrics such as
# * most tweeted hashtag in last 5 minute window
# * a map of where tweets are coming from
#
# ## Instructions
# * Insert solutions wherever it says `FILL_IN`
# * Feel free to copy/paste code from the previous notebooks, where applicable
# * Run test cells to verify that your solution is correct
#
# ## Audience
# * Primary Audience: Data Engineers
# * Additional Audiences: Data Analysts and Data Scientists
#
# ## Prerequisites
# * Web browser: current versions of Google Chrome, Firefox, Safari, Microsoft Edge and
# Internet Explorer 11 on Windows 7, 8, or 10 (see <a href="https://docs.databricks.com/user-guide/supported-browsers.html#supported-browsers#" target="_blank">Supported Web Browsers</a>)
# * Databricks Runtime 4.2 or greater
# * Completed courses Spark-SQL, DataFrames or ETL-Part 1 from <a href="https://academy.databricks.com/" target="_blank">Databricks Academy</a>, or have similar knowledge
# * Have done the rest of this course

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Getting Started</h2>
#
# Run the following cell to configure our "classroom."

# %%
# %run "./Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Initialized classroom variables & functions...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Imported Test Library...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <div>Declared various utility methods:</div>
# <li>Declared <b style="color:green">untilStreamIsReady(<i>name:String</i>)</b> to control workflow</li>
# <br/>
# <div>All done!</div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 1</h2>
# <h3>Read Streaming Data from Input Source</h3>
#
# The input source is a a Kafka feed of Twitter data
#
# For this step you will need to:
# 0. Use the `format()` operation to specify "kafka" as the type of the stream
# 0. Specify the location of the Kafka server by setting the option "kafka.bootstrap.servers" with one of the following values (depending on where you are located):
#  * **server1.databricks.training:9092** (US-Oregon)
#  * **server2.databricks.training:9092** (Singapore)
# 0. Indicate which topics to listen to by setting the option "subscribe" to "tweets"
# 0. Throttle Kafka's processing of the streams
# 0. Rewind stream to beginning when we restart notebook
# 0. Load the input data stream in as a DataFrame
# 0. Select the column `value` - cast it to a `STRING`

# %%
# TODO
from pyspark.sql.functions import col

spark.conf.set("spark.sql.shuffle.partitions", sc.defaultParallelism)

kafkaServer = "server1.databricks.training:9092"   # US (Oregon)
# kafkaServer = "server2.databricks.training:9092" # Singapore

rawDF = (spark.readStream
 .format("kafka")                                        # Specify "kafka" as the type of the stream
 .option("kafka.bootstrap.servers",kafkaServer)          # Set the location of the kafka server
 .option("subscribe","tweets")                           # Indicate which topics to listen to
 .option("maxOffsetsPerTrigger",1000)                    # Throttle Kafka's processing of the streams
 .option("startingOffsets","earliest")                   # Rewind stream to beginning when we restart notebook
 .load()                                                 # Load the input data stream in as a DataFrame
 .select(col("value").cast("STRING"))                    # Select the "value" column and cast to a string
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
schemaStr = str(rawDF.schema)

dbTest("SS-06-schema-value",     True, "(value,StringType,true)" in schemaStr)
dbTest("SS-06-is-streaming",     True, rawDF.isStreaming)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 2</h2>
# <h3>A Schema for parsing JSON</h3>
#
# Becase the schema is so complex, it is being provided for you.
#
# Simply run the following cell and proceed to the next step.

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, LongType, ArrayType

twitSchema = StructType([
  StructField("hashTags", ArrayType(StringType(), False), True),
  StructField("text", StringType(), True),   
  StructField("userScreenName", StringType(), True),
  StructField("id", LongType(), True),
  StructField("createdAt", LongType(), True),
  StructField("retweetCount", IntegerType(), True),
  StructField("lang", StringType(), True),
  StructField("favoriteCount", IntegerType(), True),
  StructField("user", StringType(), True),
  StructField("place", StructType([
    StructField("coordinates", StringType(), True), 
    StructField("name", StringType(), True),
    StructField("placeType", StringType(), True),
    StructField("fullName", StringType(), True),
    StructField("countryCode", StringType(), True)]), 
  True)
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 3</h2>
# <h3>Create a JSON DataFrame</h3>
#
# From the `rawDF` parse out the json subfields using `from_json`. Create a DataFrame that has fields
# * `time`
# * `json`, a nested field that has all the rest of the data
# * promote all `json` subfields to fields.

# %%
# TODO
from pyspark.sql.functions import from_json, expr

cleanDF = (rawDF
 .withColumn("json", from_json("value", twitSchema))                          # Add the column "json" by parsing the column "value" with "from_json"
 .select(
   expr("cast(cast(json.createdAt as double)/1000 as timestamp) as time"),   # Cast "createdAt" column properly, call it "time"
   col("json.hashTags").alias("hashTags"),                                # Promote subfields of "json" column e.g. "json.field" to "field"
   col("json.text").alias("text"),                                       # Repeat for each subfields of "json"
   col("json.userScreenName").alias("userScreenName"),                 
   col("json.id").alias("id"),
   col("json.createdAt").alias("createdAt"),
   col("json.retweetCount").alias("retweetCount"),
   col("json.lang").alias("lang"),
   col("json.favoriteCount").alias("favoriteCount"),
   col("json.user").alias("user"),
   col("json.place").alias("place"),
   col("json.place.coordinates").alias("coordinates"),
   col("json.place.name").alias("name"),
   col("json.place.placeType").alias("placeType"),
   col("json.place.fullName").alias("fullName"),
   col("json.place.countryCode").alias("countryCode")
 )
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
schemaStr = str(cleanDF.schema)

dbTest("SS-06-schema-hashTag",  True, "hashTags,ArrayType(StringType,true)" in schemaStr)
dbTest("SS-06-schema-text",  True, "(text,StringType,true)" in schemaStr)
dbTest("SS-06-schema-userScreenName",  True, "(userScreenName,StringType,true)" in schemaStr)
dbTest("SS-06-schema-id",  True, "(id,LongType,true)" in schemaStr)
dbTest("SS-06-schema-time",  True, "(time,TimestampType,true)" in schemaStr)
dbTest("SS-06-schema-retweetCount",  True, "(retweetCount,IntegerType,true)" in schemaStr)
dbTest("SS-06-schema-lang",  True, "(lang,StringType,true)" in schemaStr)
dbTest("SS-06-schema-favoriteCount",  True, "(favoriteCount,IntegerType,true)" in schemaStr)
dbTest("SS-06-schema-user",  True, "(user,StringType,true)" in schemaStr)
dbTest("SS-06-schema-coordinates",  True, "(coordinates,StringType,true)" in schemaStr)
dbTest("SS-06-schema-name",  True, "(name,StringType,true)" in schemaStr)
dbTest("SS-06-schema-placeType",  True, "(placeType,StringType,true)" in schemaStr)
dbTest("SS-06-schema-fullName",  True, "(fullName,StringType,true)" in schemaStr)
dbTest("SS-06-schema-countryCode",  True, "(countryCode,StringType,true)" in schemaStr)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 4</h2>
# <h3>Display Twitter Data as a Table</h3>
#
# Click the left-most button in the bottom left corner.

# %%
# TODO
display(cleanDF) # display "cleanDF"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>time</th><th>hashTags</th><th>text</th><th>userScreenName</th><th>id</th><th>createdAt</th><th>retweetCount</th><th>lang</th><th>favoriteCount</th><th>user</th><th>place</th><th>coordinates</th><th>name</th><th>placeType</th><th>fullName</th><th>countryCode</th></tr></thead><tbody><tr><td>2020-03-08T06:47:19.000+0000</td><td>List()</td><td>Romero did not fight like he wanted the championship bruh</td><td>cesvrmm</td><td>1236544006416302081</td><td>1583650039000</td><td>0</td><td>en</td><td>0</td><td>Cesar</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:19.000+0000</td><td>List()</td><td>Felipe Prior MVP</td><td>eduseker</td><td>1236544006395441153</td><td>1583650039000</td><td>0</td><td>en</td><td>0</td><td>Filipe</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:19.000+0000</td><td>List()</td><td>RT @AnneOrtelee: 8:50pm EST: Moon in Leo inconjunct Pluto in Capricorn. It's a power struggle, plain and simple. Triangles, drama, futile a…</td><td>nightmodesalsa</td><td>1236544006408060928</td><td>1583650039000</td><td>0</td><td>en</td><td>0</td><td>sentient fog</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:19.000+0000</td><td>List()</td><td>RT @GucciGang_EXO: After exo comeback with obsession ,whole kpop industry suddenly have different outfits on stage , mixed stage and fight…</td><td>B_light05</td><td>1236544006428844032</td><td>1583650039000</td><td>0</td><td>en</td><td>0</td><td>Baekhyunee05</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:19.000+0000</td><td>List()</td><td>RT @John_V22: If you really want to do something, you'll find a way. If you don't, you'll find an excuse.
#
# JONA ASAPFearlessVibe
#
# FearlessD…</td><td>extraJoss_</td><td>1236544006420492288</td><td>1583650039000</td><td>0</td><td>en</td><td>0</td><td>Joss Wayar</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:19.000+0000</td><td>List()</td><td>RT @epsilon3141: Added new data point on the exponential italian ICU trend (doubling every 2.6 days)
#
# It's one of the most alarming charts…</td><td>onesourgrape</td><td>1236544006429069313</td><td>1583650039000</td><td>0</td><td>en</td><td>0</td><td>One Sour Grape</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:19.000+0000</td><td>List()</td><td>@CorvidSandy @mitchellvii If we applied your idea of justice we’d all be walking around with one hand and one eye.</td><td>twatterisstupid</td><td>1236544006429061120</td><td>1583650039000</td><td>0</td><td>en</td><td>0</td><td>Twatterisstupid</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:19.000+0000</td><td>List()</td><td>RT @PreetBharara: Pinky promise you will be out of office soon with no second act in the Senate</td><td>docvicki</td><td>1236544006412062720</td><td>1583650039000</td><td>0</td><td>en</td><td>0</td><td>Dr. Vicki Weissler 🌊🌊#Resist</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:20.000+0000</td><td>List()</td><td>RT @chazzington_: big men gossiping, nothing worse.</td><td>Austin_LO9</td><td>1236544010602319872</td><td>1583650040000</td><td>0</td><td>en</td><td>0</td><td>auj.</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:20.000+0000</td><td>List()</td><td>I always miss Carson when I don’t have him with me</td><td>thealicat_</td><td>1236544010598125569</td><td>1583650040000</td><td>0</td><td>en</td><td>0</td><td>Ali✨</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:20.000+0000</td><td>List()</td><td>— At last, though, came an abrupt pause; 〝 I know you’re a pirate, and you have no reason to listen, but this is my… https://t.co/IgHw4JqGpr</td><td>FatedSuccessor</td><td>1236544010614976512</td><td>1583650040000</td><td>0</td><td>en</td><td>0</td><td>𝐎𝐍𝐄 𝐅𝐎𝐑 𝐀𝐋𝐋.</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:20.000+0000</td><td>List(Roberrt, Roberrtsecondsong, Holi)</td><td>RT @StarAshaBhat: #Roberrt #Roberrtsecondsong #Holi
# @dasadarshan @TharunSudhir
# @aanandaaudio @ArjunjanyaAJ
# March 9th 😍</td><td>KSB28460708</td><td>1236544010610552833</td><td>1583650040000</td><td>0</td><td>en</td><td>0</td><td>KSB</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:20.000+0000</td><td>List(RangBarseWithSid, SidNaaz)</td><td>Bhabhi is back with the Julous session...
#
# #RangBarseWithSid
# #SidNaaz https://t.co/1zamVMgRMP</td><td>crazy_primus</td><td>1236544010618994688</td><td>1583650040000</td><td>0</td><td>en</td><td>0</td><td>Viykram ❤️</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:20.000+0000</td><td>List(ccfinal2020, letsgo)</td><td>Hey @cardiffdevils I’m on my way #ccfinal2020 #letsgo https://t.co/Xrnsbk8Yps</td><td>HuishGregg</td><td>1236544010623373312</td><td>1583650040000</td><td>0</td><td>en</td><td>0</td><td>Gregg Huish</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:21.000+0000</td><td>List()</td><td>RT @fasiraarif: omg. i- i cant stop listening this cover https://t.co/x4KKmzFgFz</td><td>nFARIIHAH</td><td>1236544014788124672</td><td>1583650041000</td><td>0</td><td>en</td><td>0</td><td>a'a</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:21.000+0000</td><td>List()</td><td>RT @vobouji: idk what im doing https://t.co/Gj0JcovxnV</td><td>sm_bp19</td><td>1236544014796509184</td><td>1583650041000</td><td>0</td><td>en</td><td>0</td><td>นุชที่เป็นบลิ๊งกะรัต💎✨</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:21.000+0000</td><td>List()</td><td>@__uncharitable Hehehe I missed you!</td><td>kittylolo_</td><td>1236544014783922176</td><td>1583650041000</td><td>0</td><td>en</td><td>0</td><td>𝘮𝘪𝘭𝘰, 𝘫𝘪𝘸𝘰𝘯'𝘴 𝘮𝘢𝘵𝘦,</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:21.000+0000</td><td>List()</td><td>@ufc @stylebender @quietplacemovie Fight of the century</td><td>PoopNoodles</td><td>1236544014817660928</td><td>1583650041000</td><td>0</td><td>en</td><td>0</td><td>MyNameIsJeff</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-03-08T06:47:21.000+0000</td><td>List()</td><td>RT @Sophiqui: oh to be a hamster in my own luxurious water park https://t.co/NHqpKInvNt</td><td>KiSSSorn</td><td>1236544014779691008</td><td>1583650041000</td><td>0</td><td>en</td><td>0</td><td>ล็อตชิคๆเกิร์ล</td><td>List([], null, null, null, null)</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr

# %%
# TEST - Run this cell to test your solution.
dbTest("SS-06-numActiveStreams", True, len(spark.streams.active) > 0)
       
print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# When you are done, stop the stream:

# %%
# TODO
for s in spark.streams.active:
  s.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
dbTest("SS-06-numActiveStreams1", 0, len(spark.streams.active))

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 5</h2>
# <h3>Hashtag Processing</h3>
#
# In this exercise, we do ETL processing on the `hashTags` column.
#
# The goal is to first convert hash tags all to lower case then group tweets and count by hash tags.
#
# You will notice that `hashTags` is an array of hash tags, which you will have to break up (use `explode` function).
#
# The `explode` method allows you to split an array column into multiple rows, copying all the other columns into each new row.

# %%
# TODO
from pyspark.sql.functions import explode, lower, col

twitCountsDF = (cleanDF      # Start with "cleanDF"
 .withColumn("hashTag",explode("hashTags"))                  # Explode the array "hashTags" into "hashTag"
 .withColumn("hashTag",lower(col("hashTag")))                  # Convert "hashTag" to lower case
 .groupBy(col("hashTag"))                    # Aggregate by "hashTag"...
 .count()                   # For the aggregate, produce a count  
 .orderBy(col("count"))                  # Sort by "count"
 .limit(25)                 # Limit the result to 25 records
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
schemaStr = str(twitCountsDF.schema)

dbTest("SS-06-schema-hashTag", True, "(hashTag,StringType,true)" in schemaStr)
dbTest("SS-06-schema-count",   True, "(count,LongType,false)" in schemaStr)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 6</h2>
# <h3>Plot Counts of Top 25 Most Popular Hashtags</h3>
#
# Under <b>Plot Options</b>, use the following:
# * <b>Keys:</b> `hashTag`
# * <b>Values:</b> `count`
#
# In <b>Display type</b>, use <b>Pie Chart</b> and click <b>Apply</b>.
#
# Once you apply the plot options, be prepared to increase the size of the plot graphic using the resize widget in the lower right corner of the graphic area.

# %%
# TODO
display(twitCountsDF) # display twitCountsDF
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hashTag</th><th>count</th></tr></thead><tbody><tr><td>มินซูน</td><td>1</td></tr><tr><td>quebec</td><td>1</td></tr><tr><td>alsscan</td><td>1</td></tr><tr><td>goldenfbbot</td><td>1</td></tr><tr><td>pdx</td><td>1</td></tr><tr><td>gigs</td><td>1</td></tr><tr><td>doublechris</td><td>1</td></tr><tr><td>endoflife</td><td>1</td></tr><tr><td>tedx</td><td>1</td></tr><tr><td>backdoorgovt</td><td>1</td></tr><tr><td>junggaram</td><td>1</td></tr><tr><td>makebiz</td><td>1</td></tr><tr><td>when</td><td>1</td></tr><tr><td>jockstrap</td><td>1</td></tr><tr><td>neverstarmer</td><td>1</td></tr><tr><td>hunger</td><td>1</td></tr><tr><td>bonfire_photography</td><td>1</td></tr><tr><td>api</td><td>1</td></tr><tr><td>evangelion</td><td>1</td></tr><tr><td>私の好きなライブハウス</td><td>1</td></tr><tr><td>roku</td><td>1</td></tr><tr><td>linetvawards2020</td><td>1</td></tr><tr><td>oomf</td><td>1</td></tr><tr><td>nathanielwoods</td><td>1</td></tr><tr><td>kimmyungsoo</td><td>1</td></tr></tbody></table></div>

# %%
# TEST - Run this cell to test your solution.
dbTest("SS-06-numActiveStreams", True, len(spark.streams.active) > 0)
       
print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# When you are done, stop the stream:

# %%
for streamingQuery in spark.streams.active:
  streamingQuery.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 7</h2>
# <h3>Read in File with Two Letter to Three Letter Country Codes</h3>
#
# For this next part we are going to take a look at the number of requests per country.
#
# To get started, we first need a lookup table that will give us the 3-character country code.
#
# 0. Read in the file at `/mnt/training/countries/ISOCountryCodes/ISOCountryLookup.parquet`
# 0. We will be interested in the `alpha2Code` and `alpha3Code` fields later

# %%
# TODO
countryCodeDF = spark.read.parquet("/mnt/training/countries/ISOCountryCodes/ISOCountryLookup.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
schemaStr = str(countryCodeDF.schema)

dbTest("SS-06-schema-1", True, "(EnglishShortName,StringType,true)" in schemaStr)
dbTest("SS-06-schema-2", True, "(alpha2Code,StringType,true)" in schemaStr)
dbTest("SS-06-schema-3", True, "(alpha3Code,StringType,true)" in schemaStr)
dbTest("SS-06-schema-4", True, "(numericCode,StringType,true)" in schemaStr)
dbTest("SS-06-schema-5", True, "(ISO31662SubdivisionCode,StringType,true)" in schemaStr)
dbTest("SS-06-schema-6", True, "(independentTerritory,StringType,true)" in schemaStr)

dbTest("SS-06-streaming-7", False, countryCodeDF.isStreaming)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 8</h2>
# <h3>Join Tables &amp; Aggregate By Country</h3>
#
# In `cleanDF`, there is a `countryCode` field. However, it is in the form of a two-letter country code.
#
# The `display` map expects a three-letter country code.
#
# In order to retrieve tweets with three-letter country codes, we will have to join `cleanDF` with `countryCodesDF`.

# %%
# TODO
from pyspark.sql.functions import isnull
#cleanDF = (cleanDF.withColumnRenamed("place.alpha2Code", "place.countryCode"))

mappedDF = (cleanDF
  .filter(~isnull(col("place.countryCode")))                            # Filter out any nulls for "countryCode"
  .join(countryCodeDF,col("place.countryCode")==col("alpha2Code"))      # Join the two tables on "countryCode" and "alpha2Code"
  .groupBy(col("alpha3Code"))                                           # Aggregate by country, "alpha3Code"
  .count()                                                              # Produce a count of each aggregate
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
schemaStr = str(mappedDF.schema)
print(schemaStr)

dbTest("SS-06-schema-1",  True, "alpha3Code,StringType,true" in schemaStr)
dbTest("SS-06-schema-2",  True, "count,LongType,false" in schemaStr)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">StructType(List(StructField(alpha3Code,StringType,true),StructField(count,LongType,false)))
# Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 9</h2>
# <h3>Plot Tweet Counts on a World Map</h3>
#
# Under <b>Plot Options</b>, use the following:
# * <b>Keys:</b> `alpha3Code`
# * <b>Values:</b> `count`
#
# In <b>Display type</b>, use <b>World map</b> and click <b>Apply</b>.
#
# <img src="https://files.training.databricks.com/images/eLearning/Structured-Streaming/plot-options-map-06.png"/>

# %%
# TODO
display(mappedDF)  # display mappedDF
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>alpha3Code</th><th>count</th></tr></thead><tbody><tr><td>IND</td><td>60</td></tr><tr><td>CHL</td><td>2</td></tr><tr><td>GRC</td><td>1</td></tr><tr><td>MWI</td><td>3</td></tr><tr><td>BHR</td><td>1</td></tr><tr><td>NZL</td><td>6</td></tr><tr><td>KEN</td><td>5</td></tr><tr><td>TUR</td><td>1</td></tr><tr><td>PRT</td><td>1</td></tr><tr><td>CHE</td><td>1</td></tr><tr><td>ETH</td><td>1</td></tr><tr><td>LKA</td><td>1</td></tr><tr><td>DEU</td><td>3</td></tr><tr><td>AUS</td><td>22</td></tr><tr><td>NGA</td><td>31</td></tr><tr><td>NAM</td><td>4</td></tr><tr><td>PHL</td><td>25</td></tr><tr><td>ATG</td><td>1</td></tr><tr><td>MDV</td><td>1</td></tr><tr><td>SAU</td><td>2</td></tr><tr><td>POL</td><td>1</td></tr><tr><td>THA</td><td>5</td></tr><tr><td>DNK</td><td>1</td></tr><tr><td>MEX</td><td>5</td></tr><tr><td>RWA</td><td>1</td></tr><tr><td>CAN</td><td>8</td></tr><tr><td>ZMB</td><td>1</td></tr><tr><td>ARE</td><td>2</td></tr><tr><td>JAM</td><td>1</td></tr><tr><td>FRA</td><td>3</td></tr><tr><td>EGY</td><td>2</td></tr><tr><td>NLD</td><td>2</td></tr><tr><td>QAT</td><td>3</td></tr><tr><td>VNM</td><td>2</td></tr><tr><td>ITA</td><td>2</td></tr><tr><td>GHA</td><td>6</td></tr><tr><td>BRA</td><td>1</td></tr><tr><td>PAK</td><td>3</td></tr><tr><td>CMR</td><td>1</td></tr><tr><td>ESP</td><td>2</td></tr><tr><td>ZAF</td><td>33</td></tr><tr><td>JPN</td><td>1</td></tr><tr><td>NPL</td><td>1</td></tr><tr><td>USA</td><td>288</td></tr><tr><td>IRL</td><td>1</td></tr><tr><td>BEL</td><td>2</td></tr><tr><td>RUS</td><td>1</td></tr><tr><td>ECU</td><td>1</td></tr><tr><td>TWN</td><td>1</td></tr><tr><td>MYS</td><td>11</td></tr><tr><td>KOR</td><td>2</td></tr><tr><td>GBR</td><td>74</td></tr><tr><td>IDN</td><td>8</td></tr><tr><td>HUN</td><td>1</td></tr><tr><td>SWE</td><td>1</td></tr><tr><td>ZWE</td><td>3</td></tr><tr><td>CHN</td><td>3</td></tr><tr><td>SGP</td><td>2</td></tr><tr><td>TZA</td><td>3</td></tr><tr><td>UGA</td><td>4</td></tr></tbody></table></div>

# %%
# TEST - Run this cell to test your solution.
dbTest("SS-06-numActiveStreams", True, len(spark.streams.active) > 0)
       
print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 10: Write Stream</h2>
#
# Write the stream to an in-memory table
# 0. Use appropriate `format`
# 0. For this exercise, we want to append new records to the results table
# 0. Gives the query a name
# 0. Start the query
# 0. Assign the query to `mappedTable`

# %%
# TODO
mappedQuery = (mappedDF 
.writeStream                                        # From the DataFrame get the DataStreamWriter
.format("memory")                                   # Specify the sink format as "memory"
.outputMode("complete")                             # Configure the output mode as "complete"
.queryName("mappedTablePython")                     # Name the query "mappedTable-python"
.start()                                            # Start the query
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST  - Run this cell to test your solution.
dbTest("SS-06-isActive", True, mappedQuery.isActive)
dbTest("SS-06-name", "mappedTablePython", mappedQuery.name)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# Wait until stream is done initializing...

# %%
untilStreamIsReady("mappedTablePython")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The stream is active and ready.
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 11: Use SQL Syntax to Display a Few Rows</h2>
#
# Do a basic SQL query to display all columns and, say, 10 rows.
#
# ### Why are we doing this?

# %%
# %sql
SELECT *
FROM mappedTablePython
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>alpha3Code</th><th>count</th></tr></thead><tbody><tr><td>IND</td><td>18</td></tr><tr><td>MWI</td><td>1</td></tr><tr><td>BHR</td><td>1</td></tr><tr><td>NZL</td><td>2</td></tr><tr><td>KEN</td><td>3</td></tr><tr><td>AUS</td><td>8</td></tr><tr><td>ETH</td><td>1</td></tr><tr><td>NGA</td><td>7</td></tr><tr><td>NAM</td><td>2</td></tr><tr><td>SAU</td><td>1</td></tr></tbody></table></div>

# %%
# TEST - Run this cell to test your solution.
try: tableExists = (spark.table("mappedTablePython") is not None)
except: tableExists = False
dbTest("SS-06-1", True, tableExists)  

firstRowCol = spark.sql("SELECT * FROM mappedTablePython limit 1").first()[0]
dbTest("SS-06-rowsExist", True, len(firstRowCol) > 0) 

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 12: Stop Streaming Jobs</h2>
#
# Before we can conclude, we need to shut down all active streams.

# %%
# TODO
for s in spark.streams.active: # Iterate over all the active streams
    s.stop()# Stop the stream
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
dbTest("SS-06-numActiveStreams", 0, len(spark.streams.active))

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# Congratulations: ALL DONE!!

# %% [markdown]
# Don't forget to complete this short [feedback survey](https://www.surveymonkey.com/r/YCH8FYB).  Your input is extremely important and will shape future development.

# %% [markdown]
# -sandbox
# &copy; 2019 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
