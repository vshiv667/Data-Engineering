# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # Joins and Lookup Tables
#
# Apache Spark&trade; and Databricks&reg; allow you to join new records to existing tables in an ETL job.
#
# ## In this lesson you:
# * Join new records to a pre-existing lookup table
# * Employ table join best practices relevant to big data environments
#
# ## Audience
# * Primary Audience: Data Engineers
# * Additional Audiences: Data Scientists and Data Pipeline Engineers
#
# ## Prerequisites
# * Web browser: Please use a <a href="https://docs.databricks.com/user-guide/supported-browsers.html#supported-browsers" target="_blank">supported browser</a>.
# * Concept (optional): <a href="https://academy.databricks.com/collections/frontpage/products/etl-part-1-data-extraction" target="_blank">ETL Part 1 course from Databricks Academy</a>

# %% [markdown]
# <iframe
# src="//fast.wistia.net/embed/iframe/pvwi0sdvwu?videoFoam=true"
# style="border:1px solid #1cb1c2;"
# allowtransparency="true" scrolling="no" class="wistia_embed"
# name="wistia_embed" allowfullscreen mozallowfullscreen webkitallowfullscreen
# oallowfullscreen msallowfullscreen width="640" height="360" ></iframe>
# <div>
# <a target="_blank" href="https://fast.wistia.net/embed/iframe/pvwi0sdvwu?seo=false">
#   <img alt="Opens in new tab" src="https://files.training.databricks.com/static/images/external-link-icon-16x16.png"/>&nbsp;Watch full-screen.</a>
# </div>

# %% [markdown]
# -sandbox
# ### Shuffle and Broadcast Joins
#
# A common use case in ETL jobs involves joining new data to either lookup tables or historical data. You need different considerations to guide this process when working with distributed technologies such as Spark, rather than traditional databases that sit on a single machine.
#
# Traditional databases join tables by pairing values on a given column. When all the data sits in a single database, it often goes unnoticed how computationally expensive row-wise comparisons are.  When data is distributed across a cluster, the expense of joins becomes even more apparent.
#
# **A standard (or shuffle) join** moves all the data on the cluster for each table to a given node on the cluster. This is expensive not only because of the computation needed to perform row-wise comparisons, but also because data transfer across a network is often the biggest performance bottleneck of distributed systems.
#
# By contrast, **a broadcast join** remedies this situation when one DataFrame is sufficiently small. A broadcast join duplicates the smaller of the two DataFrames on each node of the cluster, avoiding the cost of shuffling the bigger DataFrame.
#
# <div><img src="https://files.training.databricks.com/images/eLearning/ETL-Part-2/shuffle-and-broadcast-joins.png" style="height: 400px; margin: 20px"/></div>

# %% [markdown]
# ### Lookup Tables
#
# Lookup tables are normally small, historical tables used to enrich new data passing through an ETL pipeline.

# %% [markdown]
# Run the cell below to mount the data.

# %%
# %run "./Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Initialized classroom variables & functions...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Imported Test Library...
# Created user-specific database
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Using the database <b style="color:green">vivek_sivalingam_rhsmith_umd_edu_dbp</b>.
# All done!

# %% [markdown]
# Import a small table that will enrich new data coming into a pipeline.

# %%
labelsDF = spark.read.parquet("/mnt/training/day-of-week")

display(labelsDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
unday</td><td>Sun</td><td>Su</td></tr><tr><td>7</td><td>2015-03-22T18:01:45</td><td>desktop</td><td>2525</td><td>Sunday</td><td>Sun</td><td>Su</td></tr><tr><td>7</td><td>2015-03-22T18:03:37</td><td>mobile</td><td>1725</td><td>Sunday</td><td>Sun</td><td>Su</td></tr><tr><td>7</td><td>2015-03-22T18:45:22</td><td>desktop</td><td>2812</td><td>Sunday</td><td>Sun</td><td>Su</td></tr><tr><td>7</td><td>2015-03-22T18:47:14</td><td>mobile</td><td>1698</td><td>Sunday</td><td>Sun</td><td>Su</td></tr><tr><td>7</td><td>2015-03-22T18:58:51</td><td>desktop</td><td>2466</td><td>Sunday</td><td>Sun</td><td>Su</td></tr><tr><td>7</td><td>2015-03-22T19:04:58</td><td>desktop</td><td>2509</td><td>Sunday</td><td>Sun</td><td>Su</td></tr><tr> ...

# %% [markdown]
# Now aggregate the results to see trends by day of the week.
#
# :NOTE: `pageviewsEnhancedDF` is a large DataFrame so it can take a while to process depending on the size of your cluster.

# %%
from pyspark.sql.functions import col

aggregatedDowDF = (pageviewsEnhancedDF
  .groupBy(col("dow"), col("longName"), col("abbreviated"), col("shortName"))  
  .sum("requests")                                             
  .withColumnRenamed("sum(requests)", "Requests")
  .orderBy(col("dow"))
)

display(aggregatedDowDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dow</th><th>longName</th><th>abbreviated</th><th>shortName</th><th>Requests</th></tr></thead><tbody><tr><td>1</td><td>Monday</td><td>Mon</td><td>M</td><td>2356818845</td></tr><tr><td>2</td><td>Tuesday</td><td>Tue</td><td>Tu</td><td>1995034884</td></tr><tr><td>3</td><td>Wednesday</td><td>Wed</td><td>W</td><td>1977615396</td></tr><tr><td>4</td><td>Thursday</td><td>Thr</td><td>Th</td><td>1931508977</td></tr><tr><td>5</td><td>Friday</td><td>Fri</td><td>F</td><td>1842512718</td></tr><tr><td>6</td><td>Saturday</td><td>Sat</td><td>Sa</td><td>1662762048</td></tr><tr><td>7</td><td>Sunday</td><td>Sun</td><td>Su</td><td>1576726066</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# ### Exploring Broadcast Joins
#
# In joining these two DataFrames together, no type of join was specified.  In order to examine this, look at the physical plan used to return the query. This can be done with the `.explain()` DataFrame method. Look for **BroadcastHashJoin** and/or **BroadcastExchange**.
#
# <div><img src="https://files.training.databricks.com/images/eLearning/ETL-Part-2/broadcasthashjoin.png" style="height: 400px; margin: 20px"/></div>

# %%
aggregatedDowDF.explain()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">== Physical Plan ==
# Sort [dow#7262 ASC NULLS FIRST], true, 0
# +- Exchange rangepartitioning(dow#7262 ASC NULLS FIRST, 200), [id=#10486]
#    +- *(3) Project [dow#7262, longName#7243, abbreviated#7244, shortName#7245, sum(cast(requests#7257 as bigint))#7294L AS Requests#7301L]
#       +- *(3) HashAggregate(keys=[dow#7262, longName#7243, abbreviated#7244, shortName#7245], functions=[finalmerge_sum(merge sum#7313L) AS sum(cast(requests#7257 as bigint))#7294L])
#          +- Exchange hashpartitioning(dow#7262, longName#7243, abbreviated#7244, shortName#7245, 200), [id=#10481]
#             +- *(2) HashAggregate(keys=[dow#7262, longName#7243, abbreviated#7244, shortName#7245], functions=[merge_sum(merge sum#7313L) AS sum#7313L])
#                +- *(2) BroadcastHashJoin [cast(dow#7262 as int)], [dow#7242], Inner, BuildRight
#                   :- *(2) HashAggregate(keys=[dow#7262], functions=[partial_sum(cast(requests#7257 as bigint)) AS sum#7313L])
#                   :  +- *(2) Project [requests#7257, date_format(cast(timestamp#7255 as timestamp), u, Some(Etc/UTC)) AS dow#7262]
#                   :     +- *(2) Filter isnotnull(date_format(cast(timestamp#7255 as timestamp), u, Some(Etc/UTC)))
#                   :        +- *(2) FileScan parquet [timestamp#7255,requests#7257] Batched: true, DataFilters: [isnotnull(date_format(cast(timestamp#7255 as timestamp), u, Some(Etc/UTC)))], Format: Parquet, Location: InMemoryFileIndex[dbfs:/mnt/training/wikipedia/pageviews/pageviews_by_second.parquet], PartitionFilters: [], PushedFilters: [], ReadSchema: struct&lt;timestamp:string,requests:int&gt;
#                   +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint))), [id=#10476]
#                      +- *(1) Project [dow#7242, longName#7243, abbreviated#7244, shortName#7245]
#                         +- *(1) Filter isnotnull(dow#7242)
#                            +- *(1) FileScan parquet [dow#7242,longName#7243,abbreviated#7244,shortName#7245] Batched: true, DataFilters: [isnotnull(dow#7242)], Format: Parquet, Location: InMemoryFileIndex[dbfs:/mnt/training/day-of-week], PartitionFilters: [], PushedFilters: [IsNotNull(dow)], ReadSchema: struct&lt;dow:int,longName:string,abbreviated:string,shortName:string&gt;
# </div>

# %% [markdown]
# By default, Spark did a broadcast join rather than a shuffle join.  In other words, it broadcast `labelsDF` to the larger `pageviewsDF`, replicating the smaller DataFrame on each node of our cluster.  This avoided having to move the larger DataFrame across the cluster.
#
# Take a look at the broadcast threshold by accessing the configuration settings.

# %%
threshold = spark.conf.get("spark.sql.autoBroadcastJoinThreshold")
print("Threshold: {0:,}".format( int(threshold) ))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Threshold: 10,485,760
# </div>

# %% [markdown]
# This is the maximize size in bytes for a table that broadcast to worker nodes.  Dropping it to `-1` disables broadcasting.

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", -1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now notice the lack of broadcast in the query physical plan.

# %%
pageviewsDF.join(labelsDF, "dow").explain()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">== Physical Plan ==
# *(3) Project [dow#7262, timestamp#7255, site#7256, requests#7257, longName#7243, abbreviated#7244, shortName#7245]
# +- *(3) SortMergeJoin [cast(dow#7262 as int)], [dow#7242], Inner
#    :- Sort [cast(dow#7262 as int) ASC NULLS FIRST], false, 0
#    :  +- Exchange hashpartitioning(cast(dow#7262 as int), 200), [id=#10580]
#    :     +- *(1) Project [timestamp#7255, site#7256, requests#7257, date_format(cast(timestamp#7255 as timestamp), u, Some(Etc/UTC)) AS dow#7262]
#    :        +- *(1) Filter isnotnull(date_format(cast(timestamp#7255 as timestamp), u, Some(Etc/UTC)))
#    :           +- *(1) FileScan parquet [timestamp#7255,site#7256,requests#7257] Batched: true, DataFilters: [isnotnull(date_format(cast(timestamp#7255 as timestamp), u, Some(Etc/UTC)))], Format: Parquet, Location: InMemoryFileIndex[dbfs:/mnt/training/wikipedia/pageviews/pageviews_by_second.parquet], PartitionFilters: [], PushedFilters: [], ReadSchema: struct&lt;timestamp:string,site:string,requests:int&gt;
#    +- Sort [dow#7242 ASC NULLS FIRST], false, 0
#       +- Exchange hashpartitioning(dow#7242, 200), [id=#10584]
#          +- *(2) Project [dow#7242, longName#7243, abbreviated#7244, shortName#7245]
#             +- *(2) Filter isnotnull(dow#7242)
#                +- *(2) FileScan parquet [dow#7242,longName#7243,abbreviated#7244,shortName#7245] Batched: true, DataFilters: [isnotnull(dow#7242)], Format: Parquet, Location: InMemoryFileIndex[dbfs:/mnt/training/day-of-week], PartitionFilters: [], PushedFilters: [IsNotNull(dow)], ReadSchema: struct&lt;dow:int,longName:string,abbreviated:string,shortName:string&gt;
# </div>

# %% [markdown]
# Next reset the original threshold.

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", threshold)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Explicitly Broadcasting Tables
#
# There are two ways of telling Spark to explicitly broadcast tables. The first is to change the Spark configuration, which affects all operations. The second is to declare it using the `broadcast()` function in the `functions` package.

# %%
from pyspark.sql.functions import broadcast

pageviewsDF.join(broadcast(labelsDF), "dow").explain()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">== Physical Plan ==
# *(2) Project [dow#7262, timestamp#7255, site#7256, requests#7257, longName#7243, abbreviated#7244, shortName#7245]
# +- *(2) BroadcastHashJoin [cast(dow#7262 as int)], [dow#7242], Inner, BuildRight
#    :- *(2) Project [timestamp#7255, site#7256, requests#7257, date_format(cast(timestamp#7255 as timestamp), u, Some(Etc/UTC)) AS dow#7262]
#    :  +- *(2) Filter isnotnull(date_format(cast(timestamp#7255 as timestamp), u, Some(Etc/UTC)))
#    :     +- *(2) FileScan parquet [timestamp#7255,site#7256,requests#7257] Batched: true, DataFilters: [isnotnull(date_format(cast(timestamp#7255 as timestamp), u, Some(Etc/UTC)))], Format: Parquet, Location: InMemoryFileIndex[dbfs:/mnt/training/wikipedia/pageviews/pageviews_by_second.parquet], PartitionFilters: [], PushedFilters: [], ReadSchema: struct&lt;timestamp:string,site:string,requests:int&gt;
#    +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint))), [id=#10649]
#       +- *(1) Project [dow#7242, longName#7243, abbreviated#7244, shortName#7245]
#          +- *(1) Filter isnotnull(dow#7242)
#             +- *(1) FileScan parquet [dow#7242,longName#7243,abbreviated#7244,shortName#7245] Batched: true, DataFilters: [isnotnull(dow#7242)], Format: Parquet, Location: InMemoryFileIndex[dbfs:/mnt/training/day-of-week], PartitionFilters: [], PushedFilters: [IsNotNull(dow)], ReadSchema: struct&lt;dow:int,longName:string,abbreviated:string,shortName:string&gt;
# </div>

# %% [markdown]
# ## Exercise 1: Join a Lookup Table
#
# Join a table that includes country name to a lookup table containing the full country name.

# %% [markdown]
# ### Step 1: Import the Data
#
# Create the following DataFrames:<br><br>
#
# - `countryLookupDF`: A lookup table with ISO country codes located at `/mnt/training/countries/ISOCountryCodes/ISOCountryLookup.parquet`
# - `logWithIPDF`: A server log including the results from an IPLookup table located at `/mnt/training/EDGAR-Log-20170329/enhanced/logDFwithIP.parquet`

# %%
# TODO
countryLookupDF = spark.read.parquet("/mnt/training/countries/ISOCountryCodes/ISOCountryLookup.parquet")

display(countryLookupDF)
logWithIPDF = spark.read.parquet("/mnt/training/EDGAR-Log-20170329/enhanced/logDFwithIP.parquet")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EnglishShortName</th><th>alpha2Code</th><th>alpha3Code</th><th>numericCode</th><th>ISO31662SubdivisionCode</th><th>independentTerritory</th></tr></thead><tbody><tr><td>Afghanistan</td><td>AF</td><td>AFG</td><td>004</td><td>ISO 3166-2:AF</td><td>Yes</td></tr><tr><td>Åland Islands</td><td>AX</td><td>ALA</td><td>248</td><td>ISO 3166-2:AX</td><td>No</td></tr><tr><td>Albania</td><td>AL</td><td>ALB</td><td>008</td><td>ISO 3166-2:AL</td><td>Yes</td></tr><tr><td>Algeria</td><td>DZ</td><td>DZA</td><td>012</td><td>ISO 3166-2:DZ</td><td>Yes</td></tr><tr><td>American Samoa</td><td>AS</td><td>ASM</td><td>016</td><td>ISO 3166-2:AS</td><td>No</td></tr><tr><td>Andorra</td><td>AD</td><td>AND</td><td>020</td><td>ISO 3166-2:AD</td><td>Yes</td></tr><tr><td>Angola</td><td>AO</td><td>AGO</td><td>024</td><td>ISO 3166-2:AO</td><td>Yes</td></tr><tr><td>Anguilla</td><td>AI</td><td>AIA</td><td>660</td><td>ISO 3166-2:AI</td><td>No</td></tr><tr><td>Antarctica</td><td>AQ</td><td>ATA</td><td>010</td><td>ISO 3166-2:AQ</td><td>No</td></tr><tr><td>Antigua and Barbuda</td><td>AG</td><td>ATG</td><td>028</td><td>ISO 3166-2:AG</td><td>Yes</td></tr><tr><td>Argentina</td><td>AR</td><td>ARG</td><td>032</td><td>ISO 3166-2:AR</td><td>Yes</td></tr><tr><td>Armenia</td><td>AM</td><td>ARM</td><td>051</td><td>ISO 3166-2:AM</td><td>Yes</td></tr><tr><td>Aruba</td><td>AW</td><td>ABW</td><td>533</td><td>ISO 3166-2:AW</td><td>No</td></tr><tr><td>Australia</td><td>AU</td><td>AUS</td><td>036</td><td>ISO 3166-2:AU</td><td>Yes</td></tr><tr><td>Austria</td><td>AT</td><td>AUT</td><td>040</td><td>ISO 3166-2:AT</td><td>Yes</td></tr><tr><td>Azerbaijan</td><td>AZ</td><td>AZE</td><td>031</td><td>ISO 3166-2:AZ</td><td>Yes</td></tr><tr><td>Bahamas</td><td>BS</td><td>BHS</td><td>044</td><td>ISO 3166-2:BS</td><td>Yes</td></tr><tr><td>Bahrain</td><td>BH</td><td>BHR</td><td>048</td><td>ISO 3166-2:BH</td><td>Yes</td></tr><tr><td>Bangladesh</td><td>BD</td><td>BGD</td><td>050</td><td>ISO 3166-2:BD</td><td>Yes</td></tr><tr><td>Barbados</td><td>BB</td><td>BRB</td><td>052</td><td>ISO 3166-2:BB</td><td>Yes</td></tr><tr><td>Belarus</td><td>BY</td><td>BLR</td><td>112</td><td>ISO 3166-2:BY</td><td>Yes</td></tr><tr><td>Belgium</td><td>BE</td><td>BEL</td><td>056</td><td>ISO 3166-2:BE</td><td>Yes</td></tr><tr><td>Belize</td><td>BZ</td><td>BLZ</td><td>084</td><td>ISO 3166-2:BZ</td><td>Yes</td></tr><tr><td>Benin</td><td>BJ</td><td>BEN</td><td>204</td><td>ISO 3166-2:BJ</td><td>Yes</td></tr><tr><td>Bermuda</td><td>BM</td><td>BMU</td><td>060</td><td>ISO 3166-2:BM</td><td>No</td></tr><tr><td>Bhutan</td><td>BT</td><td>BTN</td><td>064</td><td>ISO 3166-2:BT</td><td>Yes</td></tr><tr><td>Bolivia (Plurinational State of)</td><td>BO</td><td>BOL</td><td>068</td><td>ISO 3166-2:BO</td><td>Yes</td></tr><tr><td>Netherlands Bonaire Sint Eustatius and Saba</td><td>BQ</td><td>BES</td><td>535</td><td>ISO 3166-2:BQ</td><td>No</td></tr><tr><td>Bosnia and Herzegovina</td><td>BA</td><td>BIH</td><td>070</td><td>ISO 3166-2:BA</td><td>Yes</td></tr><tr><td>Botswana</td><td>BW</td><td>BWA</td><td>072</td><td>ISO 3166-2:BW</td><td>Yes</td></tr><tr><td>Bouvet Island</td><td>BV</td><td>BVT</td><td>074</td><td>ISO 3166-2:BV</td><td>No</td></tr><tr><td>Brazil</td><td>BR</td><td>BRA</td><td>076</td><td>ISO 3166-2:BR</td><td>Yes</td></tr><tr><td>British Indian Ocean Territory</td><td>IO</td><td>IOT</td><td>086</td><td>ISO 3166-2:IO</td><td>No</td></tr><tr><td>Brunei Darussalam</td><td>BN</td><td>BRN</td><td>096</td><td>ISO 3166-2:BN</td><td>Yes</td></tr><tr><td>Bulgaria</td><td>BG</td><td>BGR</td><td>100</td><td>ISO 3166-2:BG</td><td>Yes</td></tr><tr><td>Burkina Faso</td><td>BF</td><td>BFA</td><td>854</td><td>ISO 3166-2:BF</td><td>Yes</td></tr><tr><td>Burundi</td><td>BI</td><td>BDI</td><td>108</td><td>ISO 3166-2:BI</td><td>Yes</td></tr><tr><td>Cabo Verde</td><td>CV</td><td>CPV</td><td>132</td><td>ISO 3166-2:CV</td><td>Yes</td></ ...

# %%
display(logWithIPDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ip</th><th>date</th><th>time</th><th>zone</th><th>cik</th><th>accession</th><th>extention</th><th>code</th><th>size</th><th>idx</th><th>norefer</th><th>noagent</th><th>find</th><th>crawler</th><th>browser</th><th>IPLookupISO2</th></tr></thead><tbody><tr><td>101.71.41.ihh</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1437491.0</td><td>0001245105-17-000052</td><td>xslF345X03/primary_doc.xml</td><td>301.0</td><td>687.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>CN</td></tr><tr><td>104.196.240.dda</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1270985.0</td><td>0001188112-04-001037</td><td>.txt</td><td>200.0</td><td>7619.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td
print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ### Step 2: Broadcast the Lookup Table
#
# Complete the following:<br><br>
#
# - Create a new DataFrame `logWithIPEnhancedDF`
# - Get the full country name by performing a broadcast join that broadcasts the lookup table to the server log
# - Drop all columns other than `EnglishShortName`

# %%
from pyspark.sql.functions import col

countryLookupDF = (countryLookupDF.withColumnRenamed("alpha2Code", "IPLookupISO2"))

logWithIPEnhancedDFjoin = logWithIPDF.join(countryLookupDF, "IPLookupISO2")

logWithIPEnhancedDF = (logWithIPEnhancedDFjoin
                   .select(col("EnglishShortName"),col("ip"))
            
)

display(logWithIPEnhancedDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EnglishShortName</th><th>ip</th></tr></thead><tbody><tr><td>China</td><td>101.71.41.ihh</td></tr><tr><td>United States of America</td><td>104.196.240.dda</td></tr><tr><td>United States of America</td><td>107.23.85.jfd</td></tr><tr><td>United States of America</td><td>107.23.85.jfd</td></tr><tr><td>United States of America</td><td>107.23.85.jfd</td></tr><tr><td>United States of America</td><td>107.23.85.jfd</td></tr><tr><td>United States of America</td><td>107.23.85.jfd</td></tr><tr><td>United States of America</td><td>108.240.248.gha</td></tr><tr><td>United States of America</td><td>108.59.8.fef</td></tr><tr><td>United States of America</td><td>108.91.91.hbc</td></tr><tr><td>United States of America</td><td>108.91.91.hbc</td></tr><tr><td>United States of America</td><td>108.91.91.hbc</td></tr><tr><td>United States of America</td><td>108.91.91.hbc</td></tr><tr><td>India</td><td>115.111.104.igg</td></tr><tr><td>China</td><td>122.144.134.ggf</td></tr><tr><td>United States of America</td><td>128.186.36.jhf</td></tr><tr><td>Australia</td><td>130.194.60.cje</td></tr><tr><td>Germany</td><td>132.195.122.djf</td></tr><tr><td>Germany</td><td>132.195.122.djf</td></tr><tr><td>United States of America</td><td>137.99.128.aah</td></tr><tr><td>United States of America</td><td>137.99.128.aah</td></tr><tr><td>United States of America</td><td>137.99.128.aah</td></tr><tr><td>Hong Kong</td><td>158.132.91.haf</td></tr><tr><td>Hong Kong</td><td>158.132.91.haf</td></tr><tr><td>Hong Kong</td><td>158.132.91.haf</td></tr><tr><td>Hong Kong</td><td>158.132.91.haf</td></tr><tr><td>Hong Kong</td><td>158.132.91.haf</td></tr><tr><td>Hong Kong</td><td>158.132.91.haf</td></tr><tr><td>Hong Kong</td><td>158.132.91.haf</td></tr><tr><td>Hong Kong</td><td>158.132.91.haf</td></tr><tr><td>Hong Kong</td><td>158.132.91.haf</td></tr><tr><td>Hong Kong</td><td>158.132.91.haf</td></tr><tr><td>Hong Kong</td><td>158.132.91.haf</td></tr><tr><td>United States of America</td><td>159.45.22.jhd</td></tr><tr><td>United Kingdom of Great Britain and Northern Ireland</td><td>163.172.68.jgj</td></tr><tr><td>Korea (Republic of)</td><td>175.205.99.iah</td></tr><tr><td>Korea (Republic of)</td><td>175.205.99.iah</td></tr><tr><td>China</td><td>180.76.15.fbb</td></tr><tr><td>United States of America</td><td>192.104.20.bhg</td></tr><tr><td>United States of America</td><td>204.212.175.bch</td></tr><tr><td>United States of America</td><td>207.241.226.gcd</td></tr><tr><td>United States of America</td><td>207.241.226.hjf</td></tr><tr><td>United States of America</td><td>35.185.206.gha</td></tr><tr><td>United States of America</td><td>35.185.210.dbe</td></tr><tr><td>United States of America</td><td>35.185.214.efi</td></tr><tr><td>United States of America</td><td>47.188.54.bic</td></tr><tr><td>United States of America</td><td>50.16.61.jgj</td></tr><tr><td>United States of America</td><td>50.16.61.jgj</td></tr><tr><td>United States of America</td><td>52.52.228.bgg</td></tr><tr><td>United States of America</td><td>52.52.228.bgg</td></tr><tr><td>United States of America</td><td>52.52.228.bgg</td></tr><tr><td>United States of America</td><td>52.91.76.djb</td></tr><tr><td>United States of America</td><td>54.153.50.aaa</td></tr><tr><td>United States of America</td><td>54.193.14.gge</td></tr><tr><td>United States of America</td><td>54.212.94.jcd</td></tr><tr><td>United States of America</td><td>54.67.64.eij</td></tr><tr><td>United States of America</td><td>54.69.84.iji</td></tr><tr><td>United States of America</td><td>54.92.220.eij</td></tr><tr><td>United States of America</td><td>64.124.25.jig</td></tr><tr><td>United States of America</td><td>64.140.243.cgg</td></tr><tr><td>United States of America</td><td>64.140.243.cgg</td></tr><tr><td>United States of America</td><td>64.140.243.cgg</td></tr><tr><td>United States of America</td><td>64.212.61.haa</td></tr><tr><td>United States of Americ ...

# %%
# TEST - Run this cell to test your solution
cols = set(logWithIPEnhancedDF.columns)

dbTest("ET2-P-05-02-01", True, "EnglishShortName" in cols and "ip" in cols)
dbTest("ET2-P-05-02-02", True, "alpha2Code" not in cols and "ISO31662SubdivisionCode" not in cols)
dbTest("ET2-P-05-02-03", 5000, logWithIPEnhancedDF.count())

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ## Review
# **Question:** Why are joins expensive operations?
# **Answer:** Joins perform a large number of row-wise comparisons, making the cost associated with joining tables grow with the size of the data in the tables.
#
# **Question:** What is the difference between a shuffle and broadcast join? How does Spark manage these differences?
# **Answer:** A shuffle join shuffles data between nodes in a cluster. By contrast, a broadcast join moves the smaller of two DataFrames to where the larger DataFrame sits, minimizing the overall data transfer. By default, Spark performs a broadcast join if the total number of records is below a certain threshold. The threshold can be manually specified or you can manually specify that a broadcast join should take place. Since the automatic determination of whether a shuffle join should take place is by number of records, this could mean that really wide data would take up significantly more space per record and should therefore be specified manually.
#
# **Question:** What is a lookup table?
# **Answer:** A lookup table is small table often used for referencing commonly used data such as mapping cities to countries.

# %% [markdown]
# ## Next Steps
#
# Start the next lesson, [Database Writes]($./06-Database-Writes ).

# %% [markdown]
# ## Additional Topics & Resources
#
# **Q:** Where can I get more information on optimizing table joins where data skew is an issue?
# **A:** Check out the Databricks documentation on <a href="https://docs.databricks.com/spark/latest/spark-sql/skew-join.html" target="_blank">Skew Join Optimization</a>

# %% [markdown]
# -sandbox
# &copy; 2019 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
