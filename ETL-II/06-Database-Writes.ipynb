# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # Database Writes
#
# Apache Spark&trade; and Databricks&reg; allow you to write to a number of target databases in parallel, storing the transformed data from from your ETL job.
#
# ## In this lesson you:
# * Write to a target database in serial and in parallel
# * Repartition DataFrames to optimize table inserts
# * Coalesce DataFrames to minimize data shuffling
#
# ## Audience
# * Primary Audience: Data Engineers
# * Additional Audiences: Data Scientists and Data Pipeline Engineers
#
# ## Prerequisites
# * Web browser: Please use a <a href="https://docs.databricks.com/user-guide/supported-browsers.html#supported-browsers" target="_blank">supported browser</a>.
# * Concept (optional): <a href="https://academy.databricks.com/collections/frontpage/products/etl-part-1-data-extraction" target="_blank">ETL Part 1 course from Databricks Academy</a>

# %% [markdown]
# <iframe
# src="//fast.wistia.net/embed/iframe/ziolp0desw?videoFoam=true"
# style="border:1px solid #1cb1c2;"
# allowtransparency="true" scrolling="no" class="wistia_embed"
# name="wistia_embed" allowfullscreen mozallowfullscreen webkitallowfullscreen
# oallowfullscreen msallowfullscreen width="640" height="360" ></iframe>
# <div>
# <a target="_blank" href="https://fast.wistia.net/embed/iframe/ziolp0desw?seo=false">
#   <img alt="Opens in new tab" src="https://files.training.databricks.com/static/images/external-link-icon-16x16.png"/>&nbsp;Watch full-screen.</a>
# </div>

# %% [markdown]
# -sandbox
# ### Database Writes in Spark
#
# Writing to a database in Spark differs from other tools largely due to its distributed nature. There are a number of variables that can be tweaked to optimize performance, largely relating to how data is organized on the cluster. Partitions are the first step in understanding performant database connections.
#
# **A partition is a portion of your total data set,** which is divided into many of these portions so Spark can distribute your work across a cluster.
#
# The other concept needed to understand Spark's computation is a slot (also known as a core). **A slot/core is a resource available for the execution of computation in parallel.** In brief, a partition refers to the distribution of data while a slot refers to the distribution of computation.
#
# <div><img src="https://files.training.databricks.com/images/eLearning/ETL-Part-2/partitions-and-cores.png" style="height: 400px; margin: 20px"/></div>
#
# As a general rule of thumb, the number of partitions should be a multiple of the number of cores. For instance, with 5 partitions and 8 slots, 3 of the slots will be underutilized. With 9 partitions and 8 slots, a job will take twice as long as it waits for the extra partition to finish.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> For a refresher on connecting to databases with JDBC, see Lesson 4 of <a href="https://academy.databricks.com/collections/frontpage/products/etl-part-1-data-extraction" target="_blank">ETL Part 1 course from Databricks Academy</a>.

# %% [markdown]
# ### Managing Partitions
#
# In the context of JDBC database writes, **the number of partitions determine the number of connections used to push data through the JDBC API.** There are two ways to control this parallelism:
#
# | Function | Transformation Type | Use | Evenly distributes data across partitions? |
# | :----------------|:----------------|:----------------|:----------------|
# | `.coalesce(n)`   | narrow (does not shuffle data) | reduce the number of partitions | no |
# | `.repartition(n)`| wide (includes a shuffle operation) | increase the number of partitions | yes |

# %% [markdown]
# Run the cell below to mount the data.

# %%
# %run "./Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Initialized classroom variables & functions...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Imported Test Library...
# Created user-specific database
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Using the database <b style="color:green">vivek_sivalingam_rhsmith_umd_edu_dbp</b>.
# All done!

# %% [markdown]
# Start by importing a DataFrame of Wikipedia pageviews.

# %%
wikiDF = (spark.read
  .parquet("/mnt/training/wikipedia/pageviews/pageviews_by_second.parquet")
)
display(wikiDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>timestamp</th><th>site</th><th>requests</th></tr></thead><tbody><tr><td>2015-03-22T14:13:34</td><td>mobile</td><td>1425</td></tr><tr><td>2015-03-22T14:23:18</td><td>desktop</td><td>2534</td></tr><tr><td>2015-03-22T14:36:47</td><td>desktop</td><td>2444</td></tr><tr><td>2015-03-22T14:38:39</td><td>mobile</td><td>1488</td></tr><tr><td>2015-03-22T14:57:11</td><td>mobile</td><td>1519</td></tr><tr><td>2015-03-22T15:03:18</td><td>mobile</td><td>1559</td></tr><tr><td>2015-03-22T15:16:47</td><td>mobile</td><td>1510</td></tr><tr><td>2015-03-22T15:45:03</td><td>desktop</td><td>2673</td></tr><tr><td>2015-03-22T15:58:32</td><td>desktop</td><td>2463</td></tr><tr><td>2015-03-22T16:06:11</td><td>desktop</td><td>2525</td></tr><tr><td>2015-03-22T16:19:40</td><td>desktop</td><td>2441</td></tr><tr><td>2015-03-22T16:20:24</td><td>desktop</td><td>2781</td></tr><tr><td>2015-03-22T16:25:03</td><td>mobile</td><td>1842</td></tr><tr><td>2015-03-22T16:33:53</td><td>desktop</td><td>2549</td></tr><tr><td>2015-03-22T16:38:32</td><td>mobile</td><td>1666</td></tr><tr><td>2015-03-22T16:45:29</td><td>desktop</td><td>2601</td></tr><tr><td>2015-03-22T16:52:45</td><td>mobile</td><td>1742</td></tr><tr><td>2015-03-22T16:58:58</td><td>desktop</td><td>2559</td></tr><tr><td>2015-03-22T17:03:11</td><td>mobile</td><td>1775</td></tr><tr><td>2015-03-22T17:09:24</td><td>desktop</td><td>2469</td></tr><tr><td>2015-03-22T17:10:08</td><td>desktop</td><td>2556</td></tr><tr><td>2015-03-22T17:16:40</td><td>mobile</td><td>1798</td></tr><tr><td>2015-03-22T17:23:37</td><td>desktop</td><td>2587</td></tr><tr><td>2015-03-22T17:28:16</td><td>mobile</td><td>1717</td></tr><tr><td>2015-03-22T17:30:53</td><td>mobile</td><td>1798</td></tr><tr><td>2015-03-22T17:42:29</td><td>mobile</td><td>1784</td></tr><tr><td>2015-03-22T17:55:58</td><td>mobile</td><td>1708</td></tr><tr><td>2015-03-22T18:01:45</td><td>desktop</td><td>2525</td></tr><tr><td>2015-03-22T18:03:37</td><td>mobile</td><td>1725</td></tr><tr><td>2015-03-22T18:45:22</td><td>desktop</td><td>2812</td></tr><tr><td>2015-03-22T18:47:14</td><td>mobile</td><td>1698</td></tr><tr><td>2015-03-22T18:58:51</td><td>desktop</td><td>2466</td></tr><tr><td>2015-03-22T19:04:58</td><td>desktop</td><td>2509</td></tr><tr><td>2015-03-22T19:10:01</td><td>desktop</td><td>2593</td></tr><tr><td>2015-03-22T19:23:30</td><td>desktop</td><td>2601</td></tr><tr><td>2015-03-22T19:25:22</td><td>mobile</td><td>1666</td></tr><tr><td>2015-03-22T19:35:06</td><td>desktop</td><td>2632</td></tr><tr><td>2015-03-22T19:38:51</td><td>mobile</td><td>1762</td></tr><tr><td>2015-03-22T19:48:35</td><td>desktop</td><td>2653</td></tr><tr><td>2015-03-22T20:05:59</td><td>mobile</td><td>1731</td></tr><tr><td>2015-03-22T20:11:02</td><td>mobile</td><td>1957</td></tr><tr><td>2015-03-22T20:24:31</td><td>mobile</td><td>1856</td></tr><tr><td>2015-03-22T20:34:15</td><td>desktop</td><td>2660</td></tr><tr><td>2015-03-22T20:36:07</td><td>mobile</td><td>1965</td></tr><tr><td>2015-03-22T20:47:44</td><td>desktop</td><td>2585</td></tr><tr><td>2015-03-22T20:49:36</td><td>mobile</td><td>1859</td></tr><tr><td>2015-03-22T21:08:52</td><td>desktop</td><td>2567</td></tr><tr><td>2015-03-22T21:14:15</td><td>mobile</td><td>1956</td></tr><tr><td>2015-03-22T21:27:44</td><td>mobile</td><td>1792</td></tr><tr><td>2015-03-22T21:39:00</td><td>desktop</td><td>2467</td></tr><tr><td>2015-03-22T21:41:57</td><td>mobile</td><td>1775</td></tr><tr><td>2015-03-22T21:53:13</td><td>desktop</td><td>2476</td></tr><tr><td>2015-03-22T22:05:52</td><td>mobile</td><td>1702</td></tr><tr><td>2015-03-22T22:12:49</td><td>desktop</td><td>2515</td></tr><tr><td>2015-03-22T22:17:28</td><td>mobile</td><td>1824</td></tr><tr><td>2015-03-22T22:31:21</td><td>desktop</td><td>2504</td></tr><tr><td>2015-03-22T22:36:00</td><td>mobile</td><td>1766</td></tr><tr><td>2015-03-22T22:44:50</td><td>desktop</td><td>2397</td></tr><tr><td>2015-03-22 ...

# %% [markdown]
# View the number of partitions by changing the DataFrame into an RDD and using the `.getNumPartitions()` method.
# Since the Parquet file was saved with 5 partitions, those partitions are retained when you import the data.

# %%
partitions = wikiDF.rdd.getNumPartitions()
print("Partitions: {0:,}".format( partitions ))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Partitions: 5
# </div>

# %% [markdown]
# To increase the number of partitions to 16, use `.repartition()`.

# %%
repartitionedWikiDF = wikiDF.repartition(16)
print("Partitions: {0:,}".format( repartitionedWikiDF.rdd.getNumPartitions() ))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Partitions: 16
# </div>

# %% [markdown]
# To reduce the number of partitions, use `.coalesce()`.

# %%
coalescedWikiDF = repartitionedWikiDF.coalesce(2)
print("Partitions: {0:,}".format( coalescedWikiDF.rdd.getNumPartitions() ))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Partitions: 2
# </div>

# %% [markdown]
# -sandbox
# ### Configure Default Partitions
#
# Spark uses a default value of 200 partitions, which comes from real-world experience by Spark engineers. This is an adjustable configuration setting. Run the following cell to see this value.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> Get and set any number of different configuration settings in this manner. <a href="https://spark.apache.org/docs/latest/configuration.html" target="_blank">See the Spark documents</a> for details.

# %%
spark.conf.get("spark.sql.shuffle.partitions")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[54]: &#39;200&#39;</div>

# %% [markdown]
# Adjust the number of partitions with the following cell.  **This changes the number of partitions after a shuffle operation.**

# %%
spark.conf.set("spark.sql.shuffle.partitions", "8")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now check to see how this changes an operation involving a data shuffle, such as an `.orderBy()`.  Recall that coalesced `coalescedWikiDF` to 2 partitions.

# %%
orderByPartitions = coalescedWikiDF.orderBy("requests").rdd.getNumPartitions()
print("Partitions: {0:,}".format( orderByPartitions ))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Partitions: 8
# </div>

# %% [markdown]
# The `.orderBy()` triggered the repartition of the DataFrame into 8 partitions.  Now reset the default value.

# %%
spark.conf.set("spark.sql.shuffle.partitions", "200")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Parallel Database Writes
#
# Database writes are the inverse of what was covered in Lesson 4 of ETL Part 1.  In that lesson you defined the number of partitions in the call to the database.
#
# **By contrast and when writing to a database, the number of active connections to the database is determined by the number of partitions of the DataFrame.**

# %% [markdown]
# Examine this by writing `wikiDF` to the `/tmp` directory.  Recall that `wikiDF` has 5 partitions.

# %%
wikiDF.write.mode("OVERWRITE").parquet(userhome+"/wiki.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Examine the number of partitions in `wiki.parquet`.

# %%
for i in dbutils.fs.ls(userhome+"/wiki.parquet"):
  print(i)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">FileInfo(path=&#39;dbfs:/user/vivek.sivalingam@rhsmith.umd.edu/wiki.parquet/_committed_1374533502385465800&#39;, name=&#39;_committed_1374533502385465800&#39;, size=1723)
# FileInfo(path=&#39;dbfs:/user/vivek.sivalingam@rhsmith.umd.edu/wiki.parquet/_committed_290492210183453455&#39;, name=&#39;_committed_290492210183453455&#39;, size=2213)
# FileInfo(path=&#39;dbfs:/user/vivek.sivalingam@rhsmith.umd.edu/wiki.parquet/_committed_3845146834050335937&#39;, name=&#39;_committed_3845146834050335937&#39;, size=1523)
# FileInfo(path=&#39;dbfs:/user/vivek.sivalingam@rhsmith.umd.edu/wiki.parquet/_committed_6086086766574233815&#39;, name=&#39;_committed_6086086766574233815&#39;, size=1518)
# FileInfo(path=&#39;dbfs:/user/vivek.sivalingam@rhsmith.umd.edu/wiki.parquet/_committed_8483934640285021474&#39;, name=&#39;_committed_8483934640285021474&#39;, size=1023)
# FileInfo(path=&#39;dbfs:/user/vivek.sivalingam@rhsmith.umd.edu/wiki.parquet/_started_6086086766574233815&#39;, name=&#39;_started_6086086766574233815&#39;, size=0)
# FileInfo(path=&#39;dbfs:/user/vivek.sivalingam@rhsmith.umd.edu/wiki.parquet/part-00000-tid-6086086766574233815-bc031f63-6bb4-4bd7-8c0f-4862b366eccf-2924-1-c000.snappy.parquet&#39;, name=&#39;part-00000-tid-6086086766574233815-bc031f63-6bb4-4bd7-8c0f-4862b366eccf-2924-1-c000.snappy.parquet&#39;, size=12614518)
# FileInfo(path=&#39;dbfs:/user/vivek.sivalingam@rhsmith.umd.edu/wiki.parquet/part-00001-tid-6086086766574233815-bc031f63-6bb4-4bd7-8c0f-4862b366eccf-2925-1-c000.snappy.parquet&#39;, name=&#39;part-00001-tid-6086086766574233815-bc031f63-6bb4-4bd7-8c0f-4862b366eccf-2925-1-c000.snappy.parquet&#39;, size=12607735)
# FileInfo(path=&#39;dbfs:/user/vivek.sivalingam@rhsmith.umd.edu/wiki.parquet/part-00002-tid-6086086766574233815-bc031f63-6bb4-4bd7-8c0f-4862b366eccf-2926-1-c000.snappy.parquet&#39;, name=&#39;part-00002-tid-6086086766574233815-bc031f63-6bb4-4bd7-8c0f-4862b366eccf-2926-1-c000.snappy.parquet&#39;, size=12589725)
# FileInfo(path=&#39;dbfs:/user/vivek.sivalingam@rhsmith.umd.edu/wiki.parquet/part-00003-tid-6086086766574233815-bc031f63-6bb4-4bd7-8c0f-4862b366eccf-2927-1-c000.snappy.parquet&#39;, name=&#39;part-00003-tid-6086086766574233815-bc031f63-6bb4-4bd7-8c0f-4862b366eccf-2927-1-c000.snappy.parquet&#39;, size=12237346)
# FileInfo(path=&#39;dbfs:/user/vivek.sivalingam@rhsmith.umd.edu/wiki.parquet/part-00004-tid-6086086766574233815-bc031f63-6bb4-4bd7-8c0f-4862b366eccf-2928-1-c000.snappy.parquet&#39;, name=&#39;part-00004-tid-6086086766574233815-bc031f63-6bb4-4bd7-8c0f-4862b366eccf-2928-1-c000.snappy.parquet&#39;, size=11632976)
# </div>

# %% [markdown]
# This file has 5 parts, meaning Spark wrote the data through 5 different connections to this directory in the file system.

# %% [markdown]
# ### Examining in the Spark UI
#
# Click the arrow next to `Spark Jobs` under the following code cell in order to see a breakdown of the job you triggered. Click the next arrow to see a breakdown of the stages.

# %%
wikiDF.repartition(12).write.mode("OVERWRITE").parquet(userhome+"/wiki.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# 5 stages were initially triggered, one for each partition of our data.  When you repartitioned the DataFrame to 12 partitions, 12 stages were needed, one to write each partition of the data.  Run the following and observe how the repartitioning changes the number of stages.

# %%
wikiDF.repartition(10).write.mode("OVERWRITE").parquet(userhome+"/wiki.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# For more details, click `View` to examine the more details about the operation in the Spark UI.

# %% [markdown]
# ### A Note on Upserts
#
# Upserts insert a record into a database if it doesn't already exist, and updates the existing record if it does.  **Upserts are not supported in core Spark** due to the transactional nature of upserting and the immutable nature of Spark. You can only append or overwrite.  Databricks offers a data management system called Databricks Delta that does allow for upserts and other transactional functionality. [See the Databricks Delta docs for more information.](https://docs.databricks.com/delta/delta-batch.html#upserts-merge-into)

# %% [markdown]
# ## Exercise 1: Changing Partitions
#
# Change the number of partitions to prepare the optimal database write.

# %% [markdown]
# ### Step 1: Import Helper Functions and Data
#
# A function is defined for you to print out the number of records in each DataFrame.  Run the following cell to define that function.

# %%
def printRecordsPerPartition(df):
  '''
  Utility method to count & print the number of records in each partition
  '''
  print("Per-Partition Counts:")
  
  def countInPartition(iterator): 
    yield __builtin__.sum(1 for _ in iterator)
    
  results = (df.rdd                   # Convert to an RDD
    .mapPartitions(countInPartition)  # For each partition, count
    .collect()                        # Return the counts to the driver
  )

  for result in results: 
    print("* " + str(result))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Import the data to sitting in `/mnt/training/wikipedia/pageviews/pageviews_by_second.parquet` to `wikiDF`.

# %%
# TODO
wikiDF = ( spark.read.parquet("/mnt/training/wikipedia/pageviews/pageviews_by_second.parquet")
           )

display(wikiDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>timestamp</th><th>site</th><th>requests</th></tr></thead><tbody><tr><td>2015-03-22T14:13:34</td><td>mobile</td><td>1425</td></tr><tr><td>2015-03-22T14:23:18</td><td>desktop</td><td>2534</td></tr><tr><td>2015-03-22T14:36:47</td><td>desktop</td><td>2444</td></tr><tr><td>2015-03-22T14:38:39</td><td>mobile</td><td>1488</td></tr><tr><td>2015-03-22T14:57:11</td><td>mobile</td><td>1519</td></tr><tr><td>2015-03-22T15:03:18</td><td>mobile</td><td>1559</td></tr><tr><td>2015-03-22T15:16:47</td><td>mobile</td><td>1510</td></tr><tr><td>2015-03-22T15:45:03</td><td>desktop</td><td>2673</td></tr><tr><td>2015-03-22T15:58:32</td><td>desktop</td><td>2463</td></tr><tr><td>2015-03-22T16:06:11</td><td>desktop</td><td>2525</td></tr><tr><td>2015-03-22T16:19:40</td><td>desktop</td><td>2441</td></tr><tr><td>2015-03-22T16:20:24</td><td>desktop</td><td>2781</td></tr><tr><td>2015-03-22T16:25:03</td><td>mobile</td><td>1842</td></tr><tr><td>2015-03-22T16:33:53</td><td>desktop</td><td>2549</td></tr><tr><td>2015-03-22T16:38:32</td><td>mobile</td><td>1666</td></tr><tr><td>2015-03-22T16:45:29</td><td>desktop</td><td>2601</td></tr><tr><td>2015-03-22T16:52:45</td><td>mobile</td><td>1742</td></tr><tr><td>2015-03-22T16:58:58</td><td>desktop</td><td>2559</td></tr><tr><td>2015-03-22T17:03:11</td><td>mobile</td><td>1775</td></tr><tr><td>2015-03-22T17:09:24</td><td>desktop</td><td>2469</td></tr><tr><td>2015-03-22T17:10:08</td><td>desktop</td><td>2556</td></tr><tr><td>2015-03-22T17:16:40</td><td>mobile</td><td>1798</td></tr><tr><td>2015-03-22T17:23:37</td><td>desktop</td><td>2587</td></tr><tr><td>2015-03-22T17:28:16</td><td>mobile</td><td>1717</td></tr><tr><td>2015-03-22T17:30:53</td><td>mobile</td><td>1798</td></tr><tr><td>2015-03-22T17:42:29</td><td>mobile</td><td>1784</td></tr><tr><td>2015-03-22T17:55:58</td><td>mobile</td><td>1708</td></tr><tr><td>2015-03-22T18:01:45</td><td>desktop</td><td>2525</td></tr><tr><td>2015-03-22T18:03:37</td><td>mobile</td><td>1725</td></tr><tr><td>2015-03-22T18:45:22</td><td>desktop</td><td>2812</td></tr><tr><td>2015-03-22T18:47:14</td><td>mobile</td><td>1698</td></tr><tr><td>2015-03-22T18:58:51</td><td>desktop</td><td>2466</td></tr><tr><td>2015-03-22T19:04:58</td><td>desktop</td><td>2509</td></tr><tr><td>2015-03-22T19:10:01</td><td>desktop</td><td>2593</td></tr><tr><td>2015-03-22T19:23:30</td><td>desktop</td><td>2601</td></tr><tr><td>2015-03-22T19:25:22</td><td>mobile</td><td>1666</td></tr><tr><td>2015-03-22T19:35:06</td><td>desktop</td><td>2632</td></tr><tr><td>2015-03-22T19:38:51</td><td>mobile</td><td>1762</td></tr><tr><td>2015-03-22T19:48:35</td><td>desktop</td><td>2653</td></tr><tr><td>2015-03-22T20:05:59</td><td>mobile</td><td>1731</td></tr><tr><td>2015-03-22T20:11:02</td><td>mobile</td><td>1957</td></tr><tr><td>2015-03-22T20:24:31</td><td>mobile</td><td>1856</td></tr><tr><td>2015-03-22T20:34:15</td><td>desktop</td><td>2660</td></tr><tr><td>2015-03-22T20:36:07</td><td>mobile</td><td>1965</td></tr><tr><td>2015-03-22T20:47:44</td><td>desktop</td><td>2585</td></tr><tr><td>2015-03-22T20:49:36</td><td>mobile</td><td>1859</td></tr><tr><td>2015-03-22T21:08:52</td><td>desktop</td><td>2567</td></tr><tr><td>2015-03-22T21:14:15</td><td>mobile</td><td>1956</td></tr><tr><td>2015-03-22T21:27:44</td><td>mobile</td><td>1792</td></tr><tr><td>2015-03-22T21:39:00</td><td>desktop</td><td>2467</td></tr><tr><td>2015-03-22T21:41:57</td><td>mobile</td><td>1775</td></tr><tr><td>2015-03-22T21:53:13</td><td>desktop</td><td>2476</td></tr><tr><td>2015-03-22T22:05:52</td><td>mobile</td><td>1702</td></tr><tr><td>2015-03-22T22:12:49</td><td>desktop</td><td>2515</td></tr><tr><td>2015-03-22T22:17:28</td><td>mobile</td><td>1824</td></tr><tr><td>2015-03-22T22:31:21</td><td>desktop</td><td>2504</td></tr><tr><td>2015-03-22T22:36:00</td><td>mobile</td><td>1766</td></tr><tr><td>2015-03-22T22:44:50</td><td>desktop</td><td>2397</td></tr><tr><td>2015-03-22 ...

# %%
# TEST - Run this cell to test your solution
dbTest("ET2-P-06-01-01", 7200000, wikiDF.count())
dbTest("ET2-P-06-01-02", ['timestamp', 'site', 'requests'], wikiDF.columns)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# Print the count of records by partition using `printRecordsPerPartition()`.

# %%
printRecordsPerPartition(wikiDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Per-Partition Counts:
# * 1463276
# * 1462749
# * 1462393
# * 1463679
# * 1347903
# </div>

# %% [markdown]
# ### Step 2: Repartition the Data
#
# Define three new DataFrames:
#
# * `wikiDF1Partition`: `wikiDF` with 1 partition
# * `wikiDF16Partition`: `wikiDF` with 16 partitions
# * `wikiDF128Partition`: `wikiDF` with 128 partitions

# %%
# TODO
wikiDF1Partition =  wikiDF.repartition(1)
wikiDF16Partition =  wikiDF.repartition(16)
wikiDF128Partition =  wikiDF.repartition(128)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution

dbTest("ET2-P-06-02-01", 1, wikiDF1Partition.rdd.getNumPartitions())
dbTest("ET2-P-06-02-02", 16, wikiDF16Partition.rdd.getNumPartitions())
dbTest("ET2-P-06-02-03", 128, wikiDF128Partition.rdd.getNumPartitions())

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ### Step 3: Examine the Distribution of Records
#
# Use `printRecordsPerPartition()` to examine the distribution of records across the partitions.

# %%
# TODO
printRecordsPerPartition(wikiDF1Partition)
printRecordsPerPartition(wikiDF16Partition)
printRecordsPerPartition(wikiDF128Partition)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Per-Partition Counts:
# * 7200000
# Per-Partition Counts:
# * 450001
# * 450001
# * 450001
# * 450001
# * 450001
# * 450000
# * 450000
# * 450000
# * 449999
# * 449998
# * 449998
# * 449996
# * 450001
# * 450001
# * 450001
# * 450001
# Per-Partition Counts:
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56250
# * 56249
# * 56249
# * 56249
# * 56249
# * 56249
# * 56249
# * 56249
# * 56249
# * 56249
# * 56249
# * 56249
# * 56249
# * 56249
# * 56249
# * 56249
# * 56248
# * 56248
# * 56248
# * 56248
# * 56248
# * 56248
# * 56248
# * 56248
# * 56248
# * 56248
# * 56248
# * 56248
# * 56248
# * 56247
# * 56247
# * 56247
# * 56247
# * 56247
# * 56247
# * 56246
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# * 56251
# </div>

# %% [markdown]
# ### Step 4: Coalesce `wikiDF16Partition` and Examine the Results
#
# Coalesce `wikiDF16Partition` to `10` partitions, saving the result to `wikiDF16PartitionCoalesced`.

# %%
# TODO
wikiDF16PartitionCoalesced = repartitionedWikiDF.coalesce(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution

dbTest("ET2-P-06-03-01", 10, wikiDF16PartitionCoalesced.rdd.getNumPartitions())

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# Examine the new distribution of data using `printRecordsPerPartition`.  Is the distribution uniform?  Why or why not?

# %%
printRecordsPerPartition(wikiDF16PartitionCoalesced)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Per-Partition Counts:
# * 450001
# * 900002
# * 450001
# * 900001
# * 900000
# * 449999
# * 899996
# * 449996
# * 900002
# * 900002
# </div>

# %%
#Distribution is not Uniform. There are 10 partitions and 0.88 cores
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Review
# **Question:** How do you determine the number of connections to the database you write to?
# **Answer:** Spark makes one connection for each partition in your data. Increasing the number of partitions increases the database connections.
#
# **Question:** How do you increase and decrease the number of partitions in your data?
# **Answer:** `.repartitions(n)` increases the number of partitions in your data. It can also decrease the number of partitions, but since this is a wide operation it should be used sparingly.  `.coalesce(n)` decreases the number of partitions in your data. If you use `.coalesce(n)` with a number greater than the current partitions, this DataFrame method will have no effect.
#
# **Question:** How can you change the default number of partitions?
# **Answer:** Changing the configuration parameter `spark.sql.shuffle.partitions` will alter the default number of partitions.

# %% [markdown]
# ## Next Steps
#
# Start the next lesson, [Table Management]($./07-Table-Management ).

# %% [markdown]
# ## Additional Topics & Resources
#
# **Q:** Where can I find more information on reading the Spark UI?
# **A:** Check out the Databricks blog on <a href="https://databricks.com/blog/2015/06/22/understanding-your-spark-application-through-visualization.html" target="_blank">Understanding your Spark Application through Visualization</a>

# %% [markdown]
# -sandbox
# &copy; 2019 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
